# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "samsungs+22+ultra"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=samsungs+22+ultra'

# %%
uClient = uReq(flipkart_url)

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class" :"_1AtVbE col-12-12"})

# %%
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsungs+22+ultra&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/p
# ...

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsungs+22+ultra&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr
# ...

# %%
len(bigboxes)
# Out:
# 11

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsungs+22+ultra&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr
# ...

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32504/1792232825.py in <module>
# ----> 1 productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
#
# NameError: name 'box' is not defined

# %%
box = bigboxes[0]

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32504/1792232825.py in <module>
# ----> 1 productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
del bigboxes[0:3]

# %%
box = bigboxes[0]

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/samsung-galaxy-s22-ultra-5g-burgundy-256-gb/p/itm4a36ce5b68e8b?pid=MOBGE3ZY5QGK2HA8&lid=LSTMOBGE3ZY5QGK2HA8CRUS43&marketplace=FLIPKART&q=samsungs+22+ultra&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=e5640203-ff80-43e3-8170-3a1ec4cd2a80.MOBGE3ZY5QGK2HA8.SEARCH&ppt=None&ppn=None&ssid=x4tamxt42o0000001672573871128&qH=058cc3b440309faa'

# %%
prodRes = requests.get(productLink)

# %%
prodRes.encoding = 'utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">indian unit,great 📷  ,great  display</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_ce2700e8420b4e439e9d68bbe2f4c1be.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_b5ade0ff9a924f8386371579d849d1f0.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">amit  tungenwar </p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width
# ...

# %%
commentboxes[0].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'amit  tungenwar '

# %%
commentboxes[1].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Flipkart Customer'

# %%
commentboxes[2].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Dr.Sanchari Bhattacharyya '

# %%
commentboxes[5].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Achu Hari'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# amit  tungenwar
# Flipkart Customer
# Dr.Sanchari Bhattacharyya
# Flipkart Customer
# Flipkart Customer
# Achu Hari

# %%
commentboxes[i].div.div.div.div.text
# Out:
# '5'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.div.p.text)
    print(commentboxes[i].div.div.find_all('div', {'class': ''}))
    comTag = commentboxes[i].div.div.find_all('div', {'class': ''})
    print(comTag[0].div.text)
    print("\n")
# Out:
# amit  tungenwar
# 5
# Terrific purchase
# [<div><div class="">indian unit,great 📷  ,great  display</div><span class="_1H-bmy"><span>READ MORE</span></span></div>, <div class="">indian unit,great 📷  ,great  display</div>, <div></div>]
# indian unit,great 📷  ,great  display
#
#
# Flipkart Customer
# 5
# Awesome
# [<div><div class="">Glad that i purchased it from flipkart. in love with the phone😍😍</div><span class="_1H-bmy"><span>READ MORE</span></span></div>, <div class="">Glad that i purchased it from flipkart. in love with the phone😍😍</div>, <div></div>]
# Glad that i purchased it from flipkart. in love with the phone😍😍
#
#
# Dr.Sanchari Bhattacharyya
# 5
# Worth every penny
# [<div><div class="">excellent phone with all superb features</div><span class="_1H-bmy"><span>READ MORE</span></span></div>, <div class="">excellent phone with all superb features</div>, <div></div>]
# excellent phone with all superb features
#
#
# Flipkart Customer
# 5
# Mind-blowing purchase
# ...

# %%
commentboxes[0].div.div.find_all('div', {'class': ''})
# Out:
# [<div><div class="">indian unit,great 📷  ,great  display</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">indian unit,great 📷  ,great  display</div>,
#  <div></div>]

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.div.p.text)
    #print(commentboxes[i].div.div.find_all('div', {'class': ''}))
    comtag = commentboxes[i].div.div.find_all('div', {'class': ''})
    print(comtag[0].div.text)
    print("\n")
# Out:
# amit  tungenwar
# 5
# Terrific purchase
# indian unit,great 📷  ,great  display
#
#
# Flipkart Customer
# 5
# Awesome
# Glad that i purchased it from flipkart. in love with the phone😍😍
#
#
# Dr.Sanchari Bhattacharyya
# 5
# Worth every penny
# excellent phone with all superb features
#
#
# Flipkart Customer
# 5
# Mind-blowing purchase
# Very nice
#
#
# Flipkart Customer
# 5
# Super!
# It's really good.
#
#
# Achu Hari
# 5
# Classy product
# Excellent

# %%
#mine

from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

app = Flask(__name__)

@app.route('/',methods=['GET'])  # we are creating a route to display the home page of website
@cross_origin()
def homePage():
    return render_template('index.html')


@app.route('/review',methods=['POST', 'GET'])  # we are creating a route to show the review comments in a web UI
@cross_origin()
def index():
    if request.method == 'POST':
        try:
            searchString = request.form['content'].replace(" ", "")
            flipkart_url = "https://www.flipkart.com/search?q=" + searchString
            uClient = uReq(flipkart_url)
            flipkartPage = uClient.read()
            uClient.close()
            flipkart_html = bs(flipkartPage, "html.parser")
            bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
            del bigboxes[0:3]
            box = bigboxes[0]
            productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
            prodRes = requests.get(productLink)
            prodRes.encoding = 'utf-8'
            prod_html = bs(prodRes.text, "html.parser")
            print(prod_html)
            commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

            filename = searchString + ".csv"
            fw = open(filename, "w")   #made error and added + instead of ,
            headers = "Product, Customer Name, Rating, Heading, Comments \n"
            fw.write(headers)
            reviews = []
            for commentbox in commentboxes:
                try:
                    # name.encode(encoding='utf-8')
                    name = commentbox.div.div.find_all('p', {'class': "_2sc7ZR _2V5EHH"})[0].text #error 2 didnt add [0].text

                except:
                    name = 'No Name'

                try:
                    rating = commentbox.div.div.div.div.text

                except:
                    # rating.encode(encoding='utf-8')
                    rating = 'No rating'

                try:
                    # commentHead.encode(encoding='utf-8')
                    commentHead = commentbox.div.div.div.p.text

                except:
                    commentHead = 'No comment Heading'
                try:
                    comtag = commentbox.div.div.find_all('div', {'class': ''})
                    # custComment.encode(encoding='utf-8')
                    custComment = comtag[0].div.text
                except Exception as e:
                    print("Exception while creating a dict:", e)

                mydict = {"Product ": searchString, "Name": name, "Rating": rating, "CommentHead": commentHead,
                          "Comment": custComment}
                reviews.append(mydict)
            return render_template('results.html', reviews=reviews[0:(len(reviews)-1)])
        except Exception as e:
            print('The Exception message is: ', e)
            return 'something is wrong'

        # return render_template('results.html')
    else:
        return render_template('index.html')  #added results.html instead of index.html


if __name__ == "__main__":
    app.run(host='127.0.0.1', port=8002, debug=True)
    # app.run(debug=True)

# %%
from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

app = Flask(__name__)

@app.route('/', methods = ['GET'])
@cross_origin()
def homePage():
    return render_template('index.html')

@app.route('/review', methods = ['POST', 'GET'])
@cross_origin()
def index():
    if request.method == 'POST':
        try:
            searchString = request.form['content'].replace(" ", "")
            flipkart_url = "https://www.flipkart.com/search?q=" + searchString
            uClient = uReq(flipkart_url)
            flipkartPage = uClient.read()
            uClient.close()
            flipkart_html = bs(flipkartPage, "html.parser")
            bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
            del bigboxes[0:3]
            box = bigboxes[0]
            productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
            prodRes = requests.get(productLink)
            prodRes.encoding = 'utf-8'
            product_html = bs(prodRes.text, "html.parser")
            print(product_html)
            commentboxes = product_html.find_all("div", {"class": "_16PBlm"})

            filename = searchString + ".csv"
            fw = open(filename, "w")
            headers = "Product, Customer name, Rating, Heading, Comment \n"
            fw.write(headers)
            reviews = []
            for commentbox in commentboxes:
                try:
                    name = commentbox.div.div.find_all('p', {'class' : "_2sc7ZR _2V5EHH"})[0].text

                except:
                    name = 'No Name'

                try:
                    rating = commentbox.div.div.div.div.text

                except:
                    rating = 'No Rating'

                try:
                    commentHead = commentbox.div.div.div.p.text

                except:
                    commentHead = 'No Heading'

                try:
                    comTag = commentbox.div.div.find_all("div", {'class': ''})
                    custComment = comTag[0].div.text

                except Exception as e:
                    print("Exception while creating dictionary: ", e)

                myDict = { "Product" : searchString, "Name" : name, "Rating" : rating,
                           "CommentHead" :commentHead , "Comment" : custComment}
                reviews.append(myDict)    #review.append instead of reviews.append

            return render_template('results.html', reviews=reviews[0:(len(reviews)-1)])  #result.html instead of results.html
        except Exception as e:
            print("The Exception message is:", e)
            return 'something is wrong'

    else:
        return render_template('index.html')

if __name__ == "__main__":
    app.run(host= '127.0.0.1', port= 8003, debug=True)
